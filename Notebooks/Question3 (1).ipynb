# %% [markdown]
# Are there any notable changes or trends in house prices over the period from May 2014 to May 2015?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel("regression_data.xls")

# %%
df.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
# Convert the 'date' column to a string representation
monthly_avg_prices['date'] = monthly_avg_prices['date'].astype(str)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(monthly_avg_prices['date'], monthly_avg_prices['price'], marker='o', color='blue', linestyle='-')
plt.title('Average House Prices (May 2014 - May 2015)')
plt.xlabel('Month')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
